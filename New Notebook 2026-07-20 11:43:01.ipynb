-- %%
SHOW CATALOGS;

-- %%
SHOW SCHEMAS IN `brazillian-e-commerce`;

-- %%
SHOW TABLES IN `brazillian-e-commerce`.01_gold;

-- %%
COMMENT ON TABLE `brazillian-e-commerce`.01_gold.sales_analytics
IS 'Enterprise sales fact table used for Power BI reporting and analytics';

-- %%
DESCRIBE EXTENDED `brazillian-e-commerce`.01_gold.sales_analytics;

-- %%
SHOW TABLES IN `brazillian-e-commerce`.02_silver;

-- %%
COMMENT ON COLUMN `brazillian-e-commerce`.01_gold.sales_analytics.order_id
IS 'Unique identifier of the order';

COMMENT ON COLUMN `brazillian-e-commerce`.01_gold.sales_analytics.customer_id
IS 'Unique identifier of the customer';

COMMENT ON COLUMN `brazillian-e-commerce`.01_gold.sales_analytics.price
IS 'Price paid for the item';

COMMENT ON COLUMN `brazillian-e-commerce`.01_gold.sales_analytics.review_score
IS 'Customer review score from 1 to 5';

-- %%
ALTER TABLE `brazillian-e-commerce`.01_gold.sales_analytics SET TAGS ('domain' = 'ecommerce',  'layer' = 'gold', 'owner' = 'data-engineering');

-- %%
SHOW GRANTS ON TABLE `brazillian-e-commerce`.01_gold.sales_analytics;
